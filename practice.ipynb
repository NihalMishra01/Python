# %%
vegetables="lady finger,cabbage,potato,tomato"
fruits="mango,grapes,orange,banana"
print(f"I eat {vegetables} veggies and {fruits} fruits daily")
# Out:
# I eat lady finger,cabbage,potato,tomato veggies and mango,grapes,orange,banana fruits daily

# %%
a="Earth revolves around the sun"
print(a[6:14])
print(a[-3:])
# Out:
# revolves
# sun

# %%
s="maine 200 banana khaye"
print(s.replace("200","10").replace("banana","samosa"))
# Out:
# maine 10 samosa khaye

# %%
street = "13 patli gali"
city = "New Delhi"
country = "India"
address = street + '\n' + city + '\n' + country
print("Address using + operator:",address)
address = f'{street}\n{city}\n{country}'
print("Address using f-string:",address)
# Out:
# Address using + operator: 13 patli gali
# New Delhi
# India
# Address using f-string: 13 patli gali
# New Delhi
# India
